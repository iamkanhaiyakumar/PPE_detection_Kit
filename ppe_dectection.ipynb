# %%
# %pip install roboflow ultralytics --upgrade
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yolo 0.3.1 requires keyring==8.7.0, but you have keyring 25.6.0 which is incompatible.
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
#    ---------------------------------------- 0.0/949.8 kB ? eta -:--:--
# ...

# %%
pip install roboflow ultralytics --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import roboflow
import ultralytics

print("Roboflow version:", roboflow.__version__)
print("Ultralytics version:", ultralytics.__version__)
# Out:
# Roboflow version: 1.1.58
# Ultralytics version: 8.3.96

# %%
import sys
print("Python Path:", sys.executable)
# Out:
# Python Path: c:\Users\kanha\AppData\Local\Programs\Python\Python312\python.exe

# %%
from ultralytics import YOLO

# List of YOLOv8 model variants
models = ["yolov8n.pt", "yolov8s.pt", "yolov8m.pt", "yolov8l.pt"]
results = {}

# Train each model
for model_name in models:
    print(f"Training {model_name}...")
    model = YOLO(model_name)
    result = model.train(data="/content/Construction-Site-Safety-28/data.yaml", epochs=50, imgsz=640)
    results[model_name] = result
# Out:
# Training yolov8n.pt...
# Ultralytics 8.3.96  Python-3.12.7 torch-2.5.1+cpu CPU (11th Gen Intel Core(TM) i3-1115G4 3.00GHz)
# ...
